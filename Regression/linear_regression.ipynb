# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
X=np.array([[2],[3],[4],[5],[6]])
y=np.array([13,15,16,17,19])

model=LinearRegression()
model.fit(x,y)

print("Slope (m):", model.coef_)
print("Intercept (b):", model.intercept_)

x_new=np.array([[7]])
y_pred=model.predict(x_new)

print("Predicted score for 7 hours:", model.predict([[7]]))
plt.scatter(x,y,color='red')
plt.scatter(x_new,y_pred,color='green',label='predicted value')
plt.plot(X,model.predict(X))
plt.xlabel('Hours')
plt.ylabel('Marks')
plt.legend()
plt.grid(linewidth=0.5,linestyle="--")
plt.show()
# Out:
# Slope (m): [1.4]
# Intercept (b): 10.399999999999999
# Predicted score for 7 hours: [20.2]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes

# %%
dataset = load_diabetes()

X = dataset.data[:, 0].reshape(-1, 1)  
y = dataset.target                    

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.scatter(X, y, color='yellow', label="Actual data")
plt.plot(X, y_pred, color='blue', label="Regression line")
plt.xlabel("Feature: age (normalized)")
plt.ylabel("Disease progression")
plt.legend()
plt.grid(linestyle="--", linewidth=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression

# %%
dataset=load_diabetes()
# print(dataset.feature_names)
X=dataset.data[:,0].reshape(-1,1)
y=dataset.target

model=LinearRegression().fit(X,y)

y_pred=model.predict(X)

plt.scatter(X,y,label='Actual data',color='red')
plt.plot(X,y_pred,label='Predicted data')
plt.legend()
plt.show()
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes

# %%
dataset=load_diabetes()
x=dataset.data[:,0].reshape(-1,1)
y=dataset.target

model=LinearRegression()
model.fit(x,y)

y_pred=model.predict(x)

plt.scatter(x,y,label='Actual data',color='red')
plt.plot(x,y_pred,label='predicted data',color='blue')
plt.legend()
plt.show()
